# %%
# !pip install git+https://github.com/abey79/vsketch#egg=vsketch
# !pip install git+https://github.com/marceloprates/prettymaps.git

# !mkdir ../prints
# !mkdir ../assets
# !mkdir ../assets/Permanent_Marker/
# !wget -O ../assets/Permanent_Marker/PermanentMarker-Regular.ttf https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Out:
# ...
#   Cloning https://github.com/abey79/vsketch to /tmp/pip-install-jas3b0f0/vsketch_25427afeca9f4d4582d552e3be5af4d1
#   Running command git clone -q https://github.com/abey79/vsketch /tmp/pip-install-jas3b0f0/vsketch_25427afeca9f4d4582d552e3be5af4d1
#   Resolved https://github.com/abey79/vsketch to commit 04c70039f84656a184a6485c3a002fb8744ba1f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Cloning https://github.com/marceloprates/prettymaps.git to /tmp/pip-req-build-y8mexwja
#   Running command git clone -q https://github.com/marceloprates/prettymaps.git /tmp/pip-req-build-y8mexwja
#   Resolved https://github.com/marceloprates/prettymaps.git to commit a73cf493f003bef422ed8577f26a2dba01abf789
# ...
# mkdir: `../prints' 디렉토리를 만들 수 없습니다: 파일이 있습니다
# mkdir: `../assets' 디렉토리를 만들 수 없습니다: 파일이 있습니다
# mkdir: `../assets/Permanent_Marker/' 디렉토리를 만들 수 없습니다: 파일이 있습니다
# ...

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import vsketch
from prettymaps import *
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt

# %%
# fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)

# plot(
#     'R2709093',
    
#     ax = ax,

#     layers = {
#         'perimeter': {},
#         'water': {'tags': {'natural': ['water']}},
#     },
#     drawing_kwargs = {
#         'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
#         'water': {'fc': '#92D5F2', 'ec': '#6da8c2', 'lw': 1, 'zorder': 2},
#     },
#     osm_credit = {'text': ' '}
# )

# ax.autoscale()

# %%
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.rc.html
# 'lw'	'linewidth'
# 'ls'	'linestyle'
# 'c'	'color'
# 'fc'	'facecolor'
# 'ec'	'edgecolor'
# 'mew'	'markeredgewidth'
# 'aa'	'antialiased'
# zorder 높을 수록 더 위에 있음. 높이라고 생각하면됨

fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True, dpi=100)
dilate = 0
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['left'].set_visible(False)
for item in [fig, ax]:
    item.patch.set_visible(False)
    
plot(
    # (36.368994196775716, 127.3657408254035), radius=300,
    (36.3683644417,127.362330045), radius=300,
    ax = ax,
    layers = {
        # 'perimeter': {'circle': False, 'dilate': dilate},
        'perimeter': {},
            'streets': {
            'custom_filter': '["highway"~"motorway|trunk|primary|secondary|tertiary|residential|service|unclassified|pedestrian|footway"]',
            'width': {
                'motorway': 5,
                'trunk': 5,
                'primary': 4.5,
                'secondary': 4,
                'tertiary': 3.5,
                'residential': 3,
                'service': 2,
                'unclassified': 2,
                'pedestrian': 2,
                'footway': 1,
            }
        },
        'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
        'water': {'tags': {'natural': ['water', 'bay']}},
        'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
        'forest': {'tags': {'landuse': 'forest'}},
        'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}
    },
    drawing_kwargs = {
#         'background': {'fc': '#FFFFFF', 'ec': '#FFFFFF', 'zorder': -1},
        'perimeter': {'fc': '#FFFFFF', 'ec': '#dadbc1', 'lw': 0,  'zorder': 0},
        'green': {'fc': '#FFFFFF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
        'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
#         'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},
        'water': {'fc': '#000000', 'ec': '#000000', 'lw': 1, 'zorder': 2},        
        'parking': {'fc': '#B2B2B2', 'ec': '#B2B2B2', 'lw': 1, 'zorder': 3},
        'streets': {'fc': '#C2C2C2', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
        'building': {'fc': '#000000', 'ec': '#000000', 'lw': 1, 'zorder': 2},
    },    
#     drawing_kwargs = {
#         'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
# #         'water': {'fc': '#92D5F2', 'ec': '#6da8c2', 'lw': 1, 'zorder': 2},
#         'water': {'fc': '#000000', 'ec': '#000000', 'lw': 1, 'zorder': 2},
        
#     },
    
    osm_credit = {'text': ' '}
)

# ax.autoscale()
plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.savefig('./circular_kaist_plot.png',bbox_inches='tight', pad_inches=0.0)
# Out:
# /tmp/ipykernel_8563/834531616.py:71: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)

# %%
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.rc.html
# 'lw'	'linewidth'
# 'ls'	'linestyle'
# 'c'	'color'
# 'fc'	'facecolor'
# 'ec'	'edgecolor'
# 'mew'	'markeredgewidth'
# 'aa'	'antialiased'
# zorder 높을 수록 더 위에 있음. 높이라고 생각하면됨

fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True, dpi=100)
dilate = 0
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)
# ax.spines['left'].set_visible(False)
for item in [fig, ax]:
    item.patch.set_visible(False)
    
plot(
    (36.368994196775716, 127.3657408254035), radius=300,
    # (36.3683644417,127.362330045), radius=300,
    ax = ax,
    layers = {
        # 'perimeter': {'circle': False, 'dilate': dilate},
        'perimeter': {},
            'streets': {
            'custom_filter': '["highway"~"motorway|trunk|primary|secondary|tertiary|residential|service|unclassified|pedestrian|footway"]',
            'width': {
                'motorway': 5,
                'trunk': 5,
                'primary': 4.5,
                'secondary': 4,
                'tertiary': 3.5,
                'residential': 3,
                'service': 2,
                'unclassified': 2,
                'pedestrian': 2,
                'footway': 1,
            }
        },
        'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
        'water': {'tags': {'natural': ['water', 'bay']}},
        'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
        'forest': {'tags': {'landuse': 'forest'}},
        'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}
    },
    drawing_kwargs = {
#         'background': {'fc': '#FFFFFF', 'ec': '#FFFFFF', 'zorder': -1},
        'perimeter': {'fc': '#FFFFFF', 'ec': '#dadbc1', 'lw': 0,  'zorder': 0},
        'green': {'fc': '#FFFFFF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
        'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
#         'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},
        'water': {'fc': '#000000', 'ec': '#000000', 'lw': 1, 'zorder': 2},        
        'parking': {'fc': '#B2B2B2', 'ec': '#B2B2B2', 'lw': 1, 'zorder': 3},
        'streets': {'fc': '#C2C2C2', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
        'building': {'fc': '#000000', 'ec': '#000000', 'lw': 1, 'zorder': 2},
    },    
#     drawing_kwargs = {
#         'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
# #         'water': {'fc': '#92D5F2', 'ec': '#6da8c2', 'lw': 1, 'zorder': 2},
#         'water': {'fc': '#000000', 'ec': '#000000', 'lw': 1, 'zorder': 2},
        
#     },
    
    osm_credit = {'text': ' '}
)

# ax.autoscale()
plt.gca().set_axis_off()
plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.savefig('./circular_kaist_plot_EE.png',bbox_inches='tight', pad_inches=0.0)
# Out:
# /tmp/ipykernel_8563/3351878917.py:71: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)

# %%
from matplotlib import image
from matplotlib import pyplot
from numpy import asarray
image = image.imread('kaist.png')
print(image.dtype)
print(image.shape)
pyplot.imshow(image)
pyplot.show()
# Out:
# /home/suhu/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# float32
# (1200, 1200, 4)
